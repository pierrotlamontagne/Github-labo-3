# %%
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.optimize import curve_fit
from fonctions_maison import *
from PIL import Image
from importlib import reload
# %matplotlib inline
plt.style.use(["science","notebook","grid"])

# %%
# Importation des données
#Tout les raies
    #Vert
image_tout_fichier_382 = "Données/vert/vert_3.82ohm_45deg.bmp"
image_tout_fichier_352 = "Données/vert/vert_3.52ohm_45deg.bmp"
image_tout_fichier_329 = "Données/vert/vert_3.29ohm_45deg.bmp"
image_tout_fichier_263 = "Données/vert/vert_2.63ohm_45deg.bmp"
        #Pi
image_pi_fichier_382 = "Données/vert/vert_3.78ohm_pi.bmp"
image_pi_fichier_352 = "Données/vert/vert_3.52ohm_pi.bmp"
image_pi_fichier_329 = "Données/vert/vert_3.32ohm_pi.bmp"
image_pi_fichier_263 = "Données/vert/vert_2.62ohm_pi.bmp"
        #Sigma
image_sigma_fichier_382 = "Données/vert/vert_3.83ohm_sigma.bmp"
image_sigma_fichier_352 = "Données/vert/vert_3.51ohm_sigma.bmp"
image_sigma_fichier_329 = "Données/vert/vert_3.31ohm_sigma.bmp"
image_sigma_fichier_263 = "Données/vert/vert_2.61ohm_sigma.bmp"

    #Bleu
image_tout_fichier_252 = "Données/bleu/bleu_2.52ohm_45deg.bmp"
image_tout_fichier_281 = "Données/bleu/bleu_2.81ohm_45deg.bmp"
image_tout_fichier_304 = "Données/bleu/bleu_3.04ohm_45deg.bmp"
image_tout_fichier_324 = "Données/bleu/bleu_3.24ohm_45deg.bmp"
image_tout_fichier_357 = "Données/bleu/bleu_3.57ohm_45deg.bmp"
image_tout_fichier_372 = "Données/bleu/bleu_3.72ohm_45deg.bmp"
        #Pi
image_pi_fichier_252 = "Données/bleu/bleu_2.55ohm_pi.bmp"
image_pi_fichier_281 = "Données/bleu/bleu_2.80ohm_pi.bmp"
image_pi_fichier_304 = "Données/bleu/bleu_3.04ohm_pi.bmp"
image_pi_fichier_324 = "Données/bleu/bleu_3.23ohm_pi.bmp"
image_pi_fichier_357 = "Données/bleu/bleu_3.54ohm_pi.bmp"
image_pi_fichier_372 = "Données/bleu/bleu_3.74ohm_pi.bmp"
        #Sigma
image_sigma_fichier_252 = "Données/bleu/bleu_2.55ohm_sigma.bmp"
image_sigma_fichier_281 = "Données/bleu/bleu_2.80ohm_sigma.bmp"
image_sigma_fichier_304 = "Données/bleu/bleu_3.03ohm_sigma.bmp"
image_sigma_fichier_324 = "Données/bleu/bleu_3.24ohm_sigma.bmp"
image_sigma_fichier_357 = "Données/bleu/bleu_3.54ohm_sigma.bmp"
image_sigma_fichier_372 = "Données/bleu/bleu_3.73ohm_sigma.bmp"

# %%
data = Image.open(image_tout_fichier_252)
data_array = np.array(data)
plt.imshow(data_array[:,:,2])

# %% [markdown]
# Objet test

# %%
### Rouler cette cellule lorsqu'une modification à zeeman a été fait
import zeeman
reload(zeeman)
from zeeman import zeeman

# %%
#Vert
objet_382 = zeeman(image_tout_fichier_382, image_pi_fichier_382, image_sigma_fichier_382)
objet_352 = zeeman(image_tout_fichier_352, image_pi_fichier_352, image_sigma_fichier_352)
objet_329 = zeeman(image_tout_fichier_329, image_pi_fichier_329, image_sigma_fichier_329)
objet_263 = zeeman(image_tout_fichier_263, image_pi_fichier_263, image_sigma_fichier_263)

#Bleu
objet_252 = zeeman(image_tout_fichier_252, image_pi_fichier_252, image_sigma_fichier_252,bleu=True)
objet_281 = zeeman(image_tout_fichier_281, image_pi_fichier_281, image_sigma_fichier_281,bleu=True)
objet_304 = zeeman(image_tout_fichier_304, image_pi_fichier_304, image_sigma_fichier_304,bleu=True)
objet_324 = zeeman(image_tout_fichier_324, image_pi_fichier_324, image_sigma_fichier_324,bleu=True)
objet_357 = zeeman(image_tout_fichier_357, image_pi_fichier_357, image_sigma_fichier_357,bleu=True)
objet_372 = zeeman(image_tout_fichier_372, image_pi_fichier_372, image_sigma_fichier_372,bleu=True)

# %%
#Vert
objet_382.image()
objet_382.image_pi()
objet_382.image_sigma()

#Bleu
objet_372.image()
objet_372.image_pi()
objet_372.image_sigma()

# %%
#Vert
print("Vert")
    #3.82 Ohm
print("3.82 Ohm")
objet_382.methode_1D()
objet_382.methode_1D_pi()
objet_382.methode_1D_sigma()
    #3.52 Ohm
print("3.52 Ohm")
objet_352.methode_1D()
objet_352.methode_1D_pi()
objet_352.methode_1D_sigma()
print("3.29 Ohm")
    #3.29 Ohm
objet_329.methode_1D()
objet_329.methode_1D_pi()
objet_329.methode_1D_sigma()
print("2.63 Ohm")
    #2.63 Ohm
objet_263.methode_1D()
objet_263.methode_1D_pi()
objet_263.methode_1D_sigma()

#Bleu
print("Bleu")
    #3.72 Ohm
print("3.72 Ohm")
objet_372.methode_1D()
objet_372.methode_1D_pi()
objet_372.methode_1D_sigma()

# %% [markdown]
# En mettant `pic=1`, on choisit de visualiser le premier pic de l'image avec tous ses sous-pics qui représentent les transitions électroniques. Les pics affichés en vert se trouvent dans l'objet `.pics_array` et contient les sous-pics de chaque pic.
#
# ***Attention il faut tout de même vérifier si les sous-pics se correspondent de pic en pic visuellement!!!***
#
# ***Aussi, le premier pic en pi et sigma ne correpond pas au premier pic de la polarisation à 45 deg. Il faudra probablement changer la hauteur minimale des minimums pour pi et sigma...***

# %% [markdown]
# # Analyse des sous-pics

# %% [markdown]
# ### $\Omega = 3.82 \, ohm$

# %%
objet_382.methode_1D(pic=True)

# %%
objet_382.energie()
# Out:
# [ 43.97792773  78.58698178  78.42556798  93.19557654 110.55174224]

# %% [markdown]
# ### $\Omega = 3.52 \,ohm$

# %%
objet_352.methode_1D(pic=True)

# %%
objet_352.energie(skip=1)
# Out:
# [ 57.34658221  62.46571341  80.70086685 104.3694757  116.70418588]

# %% [markdown]
# ### $\Omega = 3.29 \,ohm$

# %%
objet_329.methode_1D(pic=True)

# %%
objet_329.energie(skip=1)
# Out:
# [ 36.98552446  55.53145001  80.26357191  99.81056178 122.59980028]

# %% [markdown]
# ### $\Omega = 2.63 \,ohm$

# %%
objet_263.methode_1D(pic=True)

# %%
objet_263.energie(skip=1)
# Out:
# c:\Users\pierr\anaconda3\lib\site-packages\scipy\optimize\minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# [ 50.69826622  82.79235581 136.88216044 135.61172801  88.50069444]

# %% [markdown]
# *J'ai créer la fonction énergie qui fait les régression linéaires automatiquement.*

# %% [markdown]
# Régression linéaire pour trouver l'énergie

# %% [markdown]
# ### ***Attention!!! Différence d'énergie entre ma méthode et la tienne. Vérfier si c'est ok.***

# %%
plt.figure(1, figsize=(6,4), dpi=400)
plt.xlabel("Rang du pic d'interférence (discret)")
plt.ylabel("Rayon des pics secondaires $r^2\ (m^2)$")
#specify x-axis locations
x_ticks = [1, 2, 3, 4, 5]
#add x-axis values to plot
plt.xticks(ticks=x_ticks)

y1, popt1, pcov1 = reg_lin(np.arange(1,len(premier_pic)+1,1) ,premier_pic**2)
plt.plot(np.arange(1,len(premier_pic)+1,1) ,premier_pic**2 , ls="none", marker="d", mec="black", mfc="none")
plt.plot(np.arange(1,len(premier_pic)+1,1) , y1 , ls="--" , color="black", label="Premier")

y2, popt2, pcov2 = reg_lin(np.arange(1,len(deuxieme_pic)+1,1) ,deuxieme_pic**2)
plt.plot(np.arange(1,len(deuxieme_pic)+1,1) ,deuxieme_pic**2 , ls="none", marker="x", mec="b", mfc="none")
plt.plot(np.arange(1,len(deuxieme_pic)+1,1) , y2 , ls="--" , color="b", label="Deuxieme")

y3, popt3, pcov3 = reg_lin(np.arange(1,len(troisieme_pic)+1,1) ,troisieme_pic**2)
plt.plot(np.arange(1,len(troisieme_pic)+1,1) ,troisieme_pic**2 , ls="none", marker="^", mec="g", mfc="none")
plt.plot(np.arange(1,len(troisieme_pic)+1,1) , y3 , ls="--" , color="g", label="Troisieme")

y4, popt4, pcov4 = reg_lin(np.arange(1,len(quatrieme_pic)+1,1) ,quatrieme_pic**2)
plt.plot(np.arange(1,len(quatrieme_pic)+1,1) ,quatrieme_pic**2 , ls="none", marker="o", mec="r", mfc="none")
plt.plot(np.arange(1,len(quatrieme_pic)+1,1) , y4 , ls="--" , color="r", label="Quatrieme")

y5, popt5, pcov5 = reg_lin(np.arange(1,len(cinquieme_pic)+1,1) ,cinquieme_pic**2)
plt.plot(np.arange(1,len(cinquieme_pic)+1,1) ,cinquieme_pic**2 , ls="none", marker="v", mec="y", mfc="none")
plt.plot(np.arange(1,len(cinquieme_pic)+1,1) , y5 , ls="--" , color="y", label="Cinquieme")

plt.legend()

parametre = np.array([[popt1, popt2, popt3, popt4, popt5], [pcov1, pcov2, pcov3, pcov4, pcov5]])

energie1 = parametre[0,0,1]/parametre[0,0,0]
energie2 = parametre[0,1,1]/parametre[0,1,0]
energie3 = parametre[0,2,1]/parametre[0,2,0]
energie4 = parametre[0,3,1]/parametre[0,3,0]
energie5 = parametre[0,4,1]/parametre[0,4,0]
energie_tot = np.array([energie1, energie2, energie3, energie4, energie5])
print(energie_tot)
# Out:
# [[[126521.         529123.        ]
#   [124721.50011678 547816.69957179]
#   [122753.70022074 567479.49934808]
#   [121374.10013665 584053.2995484 ]
#   [119959.69995977 600825.5001207 ]]
#
#  [[  5773.27475794  19147.78619888]
#   [  5526.66680452  18329.87992764]
#   [  4973.75488077  16496.078671  ]
#   [  4568.07811005  15150.60101924]
#   [  4154.16502264  13777.80676108]]]
# [4.18209625 4.39231968 4.62291156 4.81200931 5.00856121]

# %%
d = 10e-3 #!!!!!! Nous avons oublié de mesurer la mesure de "d", donc...
delta_nu = []
for i in range(len(energie_tot)-1):
    delta = (energie_tot[i+1]-energie_tot[i])/(2*d)
    delta_nu.append(delta)

print(delta_nu)    
h = 6.626e-34
delta_nu = np.array(delta_nu)
delta_E = h*delta_nu    
    
B = 0.25*np.array([2.63, 3.29, 3.52, 3.82]) #!!!!! Vérifier la formule (remplacer 0.25 par la bonnne cosntante)

y, popt, pcov = reg_lin(B, delta_E, show=True)
# Out:
# [10.511171396170615, 11.52959378679399, 9.454887552807811, 9.82759518235694]
# a = -2.0293743251129763e-33 +/- 3.056972612152536e-33 et b = 8.527039988292867e-33 +/- 2.5554707512827745e-33
