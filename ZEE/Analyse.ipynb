# %%
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib as mpl
from astropy import table
from scipy.optimize import curve_fit
from fonctions_maison import *
from PIL import Image
from zeeman import zeeman

# %%
# Importation des données
#Tout les raies
image_tout_fichier = "Données/test/image_test.bmp"
image_tout = Image.open(image_tout_fichier)
image_tout_array = np.array(image_tout)

#Pi
image_pi_fichier = "Données/test/image_test_pi.bmp"
image_pi = Image.open(image_pi_fichier)
image_pi_array = np.array(image_pi)

#Sigma
image_sigma_fichier = "Données/test/image_test_sigma.bmp"
image_sigma = Image.open(image_sigma_fichier)
image_sigma_array = np.array(image_sigma)

# %%
plt.imshow(image_tout_array[:,:,1])

# %% [markdown]
# Objet test

# %%
test = zeeman(image_tout_fichier, image_pi_fichier, image_sigma_fichier)

# %%
test.image_sigma()

# %%
test.methode_1D()
test.methode_1D_pi()
test.methode_1D_sigma()
